# %%
# !pip install -q langchain-openai langchain-core requests

# %%
pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key="GROQ_API_KEY"
)

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
  """Given 2 numbers a and b this tool returns their product"""
  return a * b

# %%
print(multiply.invoke({'a':3, 'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding

# %%
llm.invoke('hi')
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.046518664, 'completion_tokens_details': None, 'prompt_time': 0.003480229, 'prompt_tokens_details': None, 'queue_time': 0.161712339, 'total_time': 0.049998893}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f5c9d-195b-73c1-a93b-4c05055d4abb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools
# Out:
# _ChatModelBinding(bound=ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.11'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x7c567f1a9d30>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7c567ee89cd0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None), kwargs={'tools': [{'type': 'function', 'function': {'name': 'multiply', 'description': 'Given 2 numbers a an
# ...

# %%
llm_with_tools.invoke('Hi how are you ?')
# Out:
# AIMessage(content="I'm doing well, thanks for asking. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 235, 'total_tokens': 260, 'completion_time': 0.088241855, 'completion_tokens_details': None, 'prompt_time': 0.047083125, 'prompt_tokens_details': None, 'queue_time': 0.051535474, 'total_time': 0.13532498}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f5c9d-1afa-71b2-8328-4fffb86a31e0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 235, 'output_tokens': 25, 'total_tokens': 260})

# %%
query = HumanMessage('can you multiply 3 with 10')

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 10', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)

# %%
result.tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': 3, 'b': 10},
#   'id': '25kvdxbcb',
#   'type': 'tool_call'}]

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '25kvdxbcb', 'function': {'arguments': '{"a":3,"b":10}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 238, 'total_tokens': 257, 'completion_time': 0.076215904, 'completion_tokens_details': None, 'prompt_time': 0.048758984, 'prompt_tokens_details': None, 'queue_time': 0.161902443, 'total_time': 0.124974888}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f5c9d-276a-7972-8a07-59fa7e5f7144-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 10}, 'id': '25kvdxbcb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 238, 'output_tokens': 19, 'total_tokens': 257})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
 messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '25kvdxbcb', 'function': {'arguments': '{"a":3,"b":10}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 238, 'total_tokens': 257, 'completion_time': 0.076215904, 'completion_tokens_details': None, 'prompt_time': 0.048758984, 'prompt_tokens_details': None, 'queue_time': 0.161902443, 'total_time': 0.124974888}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f5c9d-276a-7972-8a07-59fa7e5f7144-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 10}, 'id': '25kvdxbcb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 238, 'output_tokens': 19, 'total_tokens': 257}),
# ...

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The result of multiplying 3 by 10 is 30.'

# %% [markdown]
# Creating tool which will convert currency

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """

  #in url keep put your api key eg: c754...
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()
# this annoted and InjectedToolArd is used it states that dont use old msg that user will give new val from other tool
# like extracting conversion_rate will feed to other tool

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1783987201,
#  'time_last_update_utc': 'Tue, 14 Jul 2026 00:00:01 +0000',
#  'time_next_update_unix': 1784073601,
#  'time_next_update_utc': 'Wed, 15 Jul 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 95.7212}

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':95.4962})
# Out:
# 954.962

# %%
#tool binding
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])

# %%
messages = [HumanMessage('What is the conversion factor between USD and INR, and based on that can you convert 80 usd to inr')]

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between USD and INR, and based on that can you convert 80 usd to inr', additional_kwargs={}, response_metadata={})]

# %%
ai_message = llm_with_tools.invoke(messages)

# %%
messages.append(ai_message)

# %%
ai_message.tool_calls
# Out:
# [{'name': 'get_conversion_factor',
#   'args': {'base_currency': 'USD', 'target_currency': 'INR'},
#   'id': '4fnffp1xf',
#   'type': 'tool_call'},
#  {'name': 'convert',
#   'args': {'base_currency_value': 80},
#   'id': '12yt4zp13',
#   'type': 'tool_call'}]

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between USD and INR, and based on that can you convert 80 usd to inr', additional_kwargs={}, response_metadata={}),
# ...

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The conversion factor between USD and INR is 95.7212. Based on this conversion factor, 80 USD is equivalent to 7657.696 INR.'
